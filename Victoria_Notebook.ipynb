non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 51.1+ KB

# %%
df.dtypes
# Out:
# Date      object
# Time      object
# CO       float64
# RH       float64
# NO2      float64
# Ozone    float64
# PM10     float64
# PM2.5    float64
# SO2      float64
# Temp     float64
# dtype: object

# %%
df.describe()
# Out:
#                CO          RH         NO2       Ozone        PM10       PM2.5  \
# count  650.000000  652.000000  642.000000  647.000000  641.000000  651.000000
# mean     1.362938   61.023957  109.251371   30.876878  200.179407  107.151920
# std      1.143655   21.611926   49.446517   36.141225  102.368756   55.488952
# min      0.210000   25.190000   30.360000    2.500000   56.300000    0.000000
# 25%      0.660000   40.670000   68.557500    3.310000  131.200000   64.100000
# 50%      1.050000   60.960000  108.630000    8.520000  178.200000   99.400000
# 75%      1.597500   82.210000  146.170000   59.905000  237.200000  129.550000
# max      6.230000   94.440000  242.630000  113.860000  609.900000  302.300000
#
#               SO2        Temp
# count  647.000000  652.000000
# mean    20.947342   19.364785
# std     21.711491    4.615735
# min      2.300000   12.820000
# 25%      6.795000   15.247500
# 50%     13.240000   18.105000
# 75%     26.975000   23.535000
# max    117.010000   29.140000

# %% [markdown]
# ### Checking for duplicated rows

# %%
# df[''.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 523 entries, 0 to 651
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    523 non-null    object
#  1   Time    523 non-null    object
#  2   CO      521 non-null    float64
#  3   RH      523 non-null    float64
#  4   NO2     513 non-null    float64
#  5   Ozone   518 non-null    float64
#  6   PM10    512 non-null    float64
#  7   PM2.5   522 non-null    float64
#  8   SO2     518 non-null    float64
#  9   Temp    523 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 44.9+ KB

# %%
df = df.replace([None], np.nan)
df.sample(20)
# Out:
#            Date   Time    CO     RH     NO2   Ozone   PM10  PM2.5    SO2  \
# 211  02-11-2019  04:45  1.13  82.68  105.30    2.85  134.7   82.8   5.20
# 435  02-12-2019  14:30  0.53  29.97   39.86  103.67  119.6   69.9  16.61
# 74   02-07-2019  18:45  1.48  47.65  217.75   15.32  164.4   90.7  24.33
# 493   2/13/2019   5:00  0.75  64.38   68.54   29.85  229.6  126.4  17.18
# 88   02-07-2019  22:15  1.50  56.44  164.89   16.19  237.4  138.0  29.21
# 286  02-11-2019  13:15  0.36  31.43   39.02   92.60    NaN    9.5  15.46
# 505   2/13/2019   8:00  1.31  61.94  113.58    8.52  197.1  107.3  73.24
# 276  02-11-2019  10:45  0.29  33.85   38.84   80.31  184.8  106.2  21.65
# 146  02-10-2019  12:30  0.28  30.48   32.99   84.73  104.8   40.8  14.08
# 13   02-07-2019  03:30  3.08  89.71  116.28    2.85  340.9  215.7   5.38
# 231  02-11-2019  09:45  0.41  41.39   57.54   60.92  181.7   99.4  52.90
# 94   02-07-2019  23:45  1.86  71.64  200.04    3.63  223.7  128.7  12.38
# 344  02-12-2019  03:45  1.71  90.63   95.06    2.77  273.4  131.1   4.27
# 556   2/13/2019  10:30  1.21  41.41   92.51   62.41  233.2  124.7  97.95
# 100  02-10-2019  01:00  0.57  72.49   58.35   24.61   65.5   48.3  10.88
# 648   2/14/2019   9:30  1.00  42.19  139.52   23.87  209.5  147.3  54.58
# 32   02-07-2019  08:15  2.28  61.11  228.38    3.34  281.0  177.1   7.48
# 499   2/13/2019   6:30  1.21  82.32  119.59    2.97  174.9  101.2   9.05
# 438  02-12-2019  15:15  0.52  27.37   41.54  105.27  119.6   68.5  18.94
# 322  02-11-2019  22:15  2.15  72.02  189.10    3.67  127.8   62.6   8.88
#
#       Temp
# 211  13.56
# 435  27.23
# 74   24.04
# 493  17.87
# 88   22.60
# 286  25.21
# 505  19.58
# 276  22.84
# 146  23.66
# 13   15.53
# 231  21.32
# 94   19.54
# 344  13.92
# 556  25.77
# 100  18.70
# 648  25.52
# 32   22.53
# 499  15.21
# 438  26.53
# 322  16.03

# %%
df.isnull().sum()
# Out:
# Date      0
# Time      0
# CO        2
# RH        0
# NO2      10
# Ozone     5
# PM10     11
# PM2.5     1
# SO2       5
# Temp      0
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'Temp']] = df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'Temp']].astype(float, errors = 'raise')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 523 entries, 0 to 651
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    523 non-null    object
#  1   Time    523 non-null    object
#  2   CO      521 non-null    float64
#  3   RH      523 non-null    float64
#  4   NO2     513 non-null    float64
#  5   Ozone   518 non-null    float64
#  6   PM10    512 non-null    float64
#  7   PM2.5   522 non-null    float64
#  8   SO2     518 non-null    float64
#  9   Temp    523 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 44.9+ KB

# %%
df['CO'].fillna(value=(df['CO'].mean()), inplace=True)
df['RH'].fillna(value=(df['RH'].mean()), inplace=True)
df['NO2'].fillna(value=(df['NO2'].mean()), inplace=True)
df['Ozone'].fillna(value=(df['Ozone'].mean()), inplace=True)
df['PM10'].fillna(value=(df['PM10'].mean()), inplace=True)
df['PM2.5'].fillna(value=(df['PM2.5'].mean()), inplace=True)
df['SO2'].fillna(value=(df['SO2'].mean()), inplace=True)
df['Temp'].fillna(value=(df['Temp'].mean()), inplace=True)

# %%
# removed null values
df.isnull().sum()
# Out:
# Date     0
# Time     0
# CO       0
# RH       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# Temp     0
# dtype: int64

# %%
df.describe()
# Out:
#                CO          RH         NO2       Ozone        PM10       PM2.5  \
# count  523.000000  523.000000  523.000000  523.000000  523.000000  523.000000
# mean     1.384242   58.326004  109.362963   34.776988  198.348047  105.974521
# std      1.237065   21.705911   52.797429   37.687884  109.981025   60.337530
# min      0.210000   25.190000   30.360000    2.500000   56.300000    0.000000
# 25%      0.620000   37.160000   63.440000    3.630000  121.650000   59.550000
# 50%      1.000000   56.110000  108.530000   13.450000  174.900000   94.900000
# 75%      1.695000   79.230000  152.320000   71.110000  236.400000  129.550000
# max      6.230000   94.440000  242.630000  113.860000  609.900000  302.300000
#
#               SO2        Temp
# count  523.000000  523.000000
# mean    20.476853   20.002753
# std     19.357647    4.626360
# min      2.300000   12.820000
# 25%      8.215000   15.715000
# 50%     14.300000   18.990000
# 75%     26.350000   24.285000
# max    117.010000   29.140000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)

# %%
# plt.figure(figsize=(10, 7))

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2',
#        'Temp'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 7))
plt.boxplot(df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2']])
plt.xlabel("Factors affecting Air Quality")
# Out:
# Text(0.5, 0, 'Factors affecting Air Quality')

# %%
# removing outlier based on PM10
mean=df['PM10'].mean()
std_deviation=df['PM10'].std()
low_out=mean-3*std_deviation
high_out=mean+3*std_deviation
df=df[(df['PM10'] < high_out) & (df['PM10'] > low_out)]
df.reset_index()
# Out:
#      index        Date   Time    CO     RH     NO2  Ozone   PM10  PM2.5  \
# 0        0  02-07-2019  00:15  4.54  76.26  175.87   4.19  371.7  203.1
# 1        1  02-07-2019  00:30  5.10  79.29  179.45   4.16  371.7  203.1
# 2        2  02-07-2019  00:45  5.05  79.13  177.07   4.14  371.7  203.1
# 3        3  02-07-2019  01:00  4.83  80.05  172.13   4.17  423.3  217.0
# 4        4  02-07-2019  01:15  4.03  80.90  150.14   3.75  423.9  217.0
# ..     ...         ...    ...   ...    ...     ...    ...    ...    ...
# 502    647   2/14/2019   9:15  0.96  42.61  130.15  21.48  224.6  151.1
# 503    648   2/14/2019   9:30  1.00  42.19  139.52  23.87  209.5  147.3
# 504    649   2/14/2019   9:45  0.86  41.18  116.08  38.81  209.5  147.3
# 505    650   2/14/2019  10:00  0.81  39.69   95.34  53.16  209.5  147.3
# 506    651   2/14/2019  10:15  0.93  38.74  111.23  52.32  209.5  146.2
#
#        SO2   Temp
# 0     8.26  17.65
# 1    15.00  16.82
# 2    14.12  16.86
# 3    13.06  16.62
# 4    10.68  16.39
# ..     ...    ...
# 502  56.79  24.79
# 503  54.58  25.52
# 504  54.44  25.96
# 505  70.74  26.23
# 506  84.46  26.85
#
# [507 rows x 11 columns]

# %%
# shape of new dataframe
df.shape
# Out:
# (507, 10)

# %%
plt.figure(figsize=(10, 7))
plt.boxplot(df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2']])
plt.xlabel("Factors affecting Air Quality")
# Out:
# Text(0.5, 0, 'Factors affecting Air Quality')

# %%
df.head()
# Out:
#          Date   Time    CO     RH     NO2  Ozone   PM10  PM2.5    SO2   Temp
# 0  02-07-2019  00:15  4.54  76.26  175.87   4.19  371.7  203.1   8.26  17.65
# 1  02-07-2019  00:30  5.10  79.29  179.45   4.16  371.7  203.1  15.00  16.82
# 2  02-07-2019  00:45  5.05  79.13  177.07   4.14  371.7  203.1  14.12  16.86
# 3  02-07-2019  01:00  4.83  80.05  172.13   4.17  423.3  217.0  13.06  16.62
# 4  02-07-2019  01:15  4.03  80.90  150.14   3.75  423.9  217.0  10.68  16.39

# %%
df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2']].describe()
# Out:
#                CO          RH         NO2       Ozone        PM10       PM2.5  \
# count  507.000000  507.000000  507.000000  507.000000  507.000000  507.000000
# mean     1.274198   57.307692  108.454812   35.766676  186.095520  100.091863
# std      1.061855   21.255517   53.209775   37.857604   86.829139   51.154421
# min      0.210000   25.190000   30.360000    2.500000   56.300000    0.000000
# 25%      0.620000   36.930000   59.795000    3.660000  119.950000   59.300000
# 50%      0.950000   55.330000  106.750000   14.960000  171.900000   91.900000
# 75%      1.550000   78.035000  152.130000   74.235000  230.000000  128.350000
# max      6.230000   94.380000  242.630000  113.860000  523.900000  296.400000
#
#               SO2
# count  507.000000
# mean    20.834446
# std     19.550001
# min      2.300000
# 25%      8.230000
# 50%     14.620000
# 75%     26.975000
# max    117.010000

# %%
df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2']].plot(figsize=(16,6))
plt.xlabel('Count')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
plt.hist(df[['CO']], bins=10, rwidth=0.75)
# Out:
# (array([212., 145.,  61.,  47.,  14.,   6.,   4.,   9.,   4.,   5.]),
#  array([0.21 , 0.812, 1.414, 2.016, 2.618, 3.22 , 3.822, 4.424, 5.026,
#         5.628, 6.23 ]),
#  <BarContainer object of 10 artists>)

# %%
df[['NO2']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['Ozone']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['PM2.5']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['PM10']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
6.2, 5.7, 4.6, 5.4, 5.9, 4.3, 5.1, 5.2, 4.9, 9.0
# Out:
# (6.2, 5.7, 4.6, 5.4, 5.9, 4.3, 5.1, 5.2, 4.9, 9.0)

# %%
sns.distplot(df['CO'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CO', ylabel='Density'>

# %%
sns.distplot(df['RH'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RH', ylabel='Density'>

# %%
sns.distplot(df['NO2'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='NO2', ylabel='Density'>

# %%
sns.distplot(df['Ozone'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Ozone', ylabel='Density'>

# %%
sns.distplot(df['PM10'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM10', ylabel='Density'>

# %%
sns.distplot(df['PM2.5'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PM2.5', ylabel='Density'>

# %%
sns.distplot(df['SO2'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SO2', ylabel='Density'>

# %% [markdown]
# ### Calculating Sub Indexes of different features affecting AQI based on Correlation Matrix

# %%
# PM10 Sub-Index calculation
def get_PM10_subindex(x):
    if x <= 50:
        return x
    elif x > 50 and x <= 100:
        return x
    elif x > 100 and x <= 250:
        return 100 + (x - 100) * 100 / 150
    elif x > 250 and x <= 350:
        return 200 + (x - 250)
    elif x > 350 and x <= 430:
        return 300 + (x - 350) * 100 / 80
    elif x > 430:
        return 400 + (x - 430) * 100 / 80
    else:
        return 0
    
df["PM10_SubIndex"] = df["PM10"].astype(int).apply(lambda x: get_PM10_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/837377662.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PM10_SubIndex"] = df["PM10"].astype(int).apply(lambda x: get_PM10_subindex(x))

# %%
# PM2.5 Sub-Index calculation
def get_PM25_subindex(x):
    if x <= 30:
        return x * 50 / 30
    elif x > 30 and x <= 60:
        return 50 + (x - 30) * 50 / 30
    elif x > 60 and x <= 90:
        return 100 + (x - 60) * 100 / 30
    elif x > 90 and x <= 120:
        return 200 + (x - 90) * 100 / 30
    elif x > 120 and x <= 250:
        return 300 + (x - 120) * 100 / 130
    elif x > 250:
        return 400 + (x - 250) * 100 / 130
    else:
        return 0

df["PM2.5_SubIndex"] = df["PM2.5"].astype(int).apply(lambda x: get_PM25_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/1245678504.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PM2.5_SubIndex"] = df["PM2.5"].astype(int).apply(lambda x: get_PM25_subindex(x))

# %%
# SO2 Sub-Index calculation
def get_SO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 380:
        return 100 + (x - 80) * 100 / 300
    elif x > 380 and x <= 800:
        return 200 + (x - 380) * 100 / 420
    elif x > 800 and x <= 1600:
        return 300 + (x - 800) * 100 / 800
    elif x > 1600:
        return 400 + (x - 1600) * 100 / 800
    else:
        return 0

df["SO2_SubIndex"] = df["SO2"].astype(int).apply(lambda x: get_SO2_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/4072100297.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SO2_SubIndex"] = df["SO2"].astype(int).apply(lambda x: get_SO2_subindex(x))

# %%
# NO2 Sub-Index calculation
def get_NO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 180:
        return 100 + (x - 80) * 100 / 100
    elif x > 180 and x <= 280:
        return 200 + (x - 180) * 100 / 100
    elif x > 280 and x <= 400:
        return 300 + (x - 280) * 100 / 120
    elif x > 400:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

df["NO2_SubIndex"] = df["NO2"].astype(int).apply(lambda x: get_NO2_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/1061408014.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NO2_SubIndex"] = df["NO2"].astype(int).apply(lambda x: get_NO2_subindex(x))

# %%
# Ozone Sub-Index calculation
def get_Ozone_subindex(x):
    if x <= 50:
        return x * 50 / 50
    elif x > 50 and x <= 100:
        return 50 + (x - 50) * 50 / 50
    elif x > 100 and x <= 168:
        return 100 + (x - 100) * 100 / 68
    elif x > 168 and x <= 208:
        return 200 + (x - 168) * 100 / 40
    elif x > 208 and x <= 748:
        return 300 + (x - 208) * 100 / 539
    elif x > 748:
        return 400 + (x - 400) * 100 / 539
    else:
        return 0

df["Ozone_SubIndex"] = df["Ozone"].astype(int).apply(lambda x: get_Ozone_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/3412462845.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ozone_SubIndex"] = df["Ozone"].astype(int).apply(lambda x: get_Ozone_subindex(x))

# %%
# Removing columns
df.drop(['Date', 'Time', 'Temp', 'RH'], axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
def get_CO_subindex(x):
    if x <= 1:
        return x * 50 / 1
    elif x <= 2:
        return 50 + (x - 1) * 50 / 1
    elif x <= 10:
        return 100 + (x - 2) * 100 / 8
    elif x <= 17:
        return 200 + (x - 10) * 100 / 7
    elif x <= 34:
        return 300 + (x - 17) * 100 / 17
    elif x > 34:
        return 400 + (x - 34) * 100 / 17
    else:
        return 0

df["CO_SubIndex"] = df["CO"].apply(lambda x: get_CO_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/2719783207.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CO_SubIndex"] = df["CO"].apply(lambda x: get_CO_subindex(x))

# %%
df["AQI"] = (round(df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex']].max(axis = 1)))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/4100597417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AQI"] = (round(df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex']].max(axis = 1)))

# %%
df.columns
# Out:
# Index(['CO', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'PM10_SubIndex',
#        'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex',
#        'CO_SubIndex', 'AQI'],
#       dtype='object')

# %%
def AQI_Range(x):
    if x<=50:
        return "Good"
    elif x>50 and x<=100:
        return "Moderate"
    elif x>100 and x<=200:
        return "Poor"
    elif x>200 and x<=300:
        return "Unhealthy"
    elif x>300 and x<=400:
        return "Very unhealthy"
    elif x>400:
        return "Hazardous"

df['AQI_Range'] = df['AQI'] .apply(AQI_Range)
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/2681342920.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AQI_Range'] = df['AQI'] .apply(AQI_Range)

# %%
def get_AQI_Bucket(x):
    if x=='Good':
        return 0
    elif x=='Moderate':
        return 1
    elif x=='Poor':
        return 2
    elif x=='Unhealthy':
        return 3
    elif x=='Very unhealthy':
        return 4
    else:
        return 5
    
df["AQI_Bucket"]=df["AQI"].apply(lambda x: get_AQI_Bucket(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_8680/3488882346.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AQI_Bucket"]=df["AQI"].apply(lambda x: get_AQI_Bucket(x))

# %%
df.head()
# Out:
#      CO     NO2  Ozone   PM10  PM2.5    SO2  PM10_SubIndex  PM2.5_SubIndex  \
# 0  4.54  175.87   4.19  371.7  203.1   8.26         326.25      363.846154
# 1  5.10  179.45   4.16  371.7  203.1  15.00         326.25      363.846154
# 2  5.05  177.07   4.14  371.7  203.1  14.12         326.25      363.846154
# 3  4.83  172.13   4.17  423.3  217.0  13.06         391.25      374.615385
# 4  4.03  150.14   3.75  423.9  217.0  10.68         391.25      374.615385
#
#    SO2_SubIndex  NO2_SubIndex  Ozone_SubIndex  CO_SubIndex    AQI  \
# 0         10.00         195.0             4.0      131.750  364.0
# 1         18.75         199.0             4.0      138.750  364.0
# 2         17.50         197.0             4.0      138.125  364.0
# 3         16.25         192.0             4.0      135.375  391.0
# 4         12.50         170.0             3.0      125.375  391.0
#
#         AQI_Range  AQI_Bucket
# 0  Very unhealthy           5
# 1  Very unhealthy           5
# 2  Very unhealthy           5
# 3  Very unhealthy           5
# 4  Very unhealthy           5

# %%
df['AQI'].unique()
# Out:
# array([364., 391., 371., 373., 362., 358., 351., 340., 344., 353., 322.,
#        305., 213., 243., 237., 227., 200., 209., 205., 247., 262., 261.,
#        231., 260., 307., 314., 306., 302.,  85.,  80.,  92.,  91.,  94.,
#         96., 104., 107., 110., 117., 109., 106., 103., 101.,  88.,  73.,
#         75.,  70.,  72.,  76., 102.,  93., 119., 122., 128., 144., 160.,
#        169., 180., 170., 175., 178., 179., 165., 155., 154., 176., 174.,
#        172., 173., 163., 162., 161., 151., 147., 203., 267., 240., 230.,
#        253., 183., 250., 129.,  97., 116., 120., 145., 187., 188., 185.,
#        191., 211., 216., 217., 212., 193., 192., 182., 184., 195., 199.,
#        190., 297., 300., 303., 304., 308., 310., 311., 317., 316., 220.,
#        157., 130., 127., 113., 112.,  98., 114., 132., 186., 196., 210.,
#        223., 301., 315., 318., 335., 342., 324., 321., 277., 270., 257.,
#        283., 290., 263., 197., 289., 309., 452., 399., 198., 208., 334.,
#        338., 369., 389., 516., 435., 402., 397., 365., 337., 320.])

# %%
# Removed Ozone_SubIndex as it is negatively correlated with CO_SubIndex and NO2_SubIndex
X=df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'CO_SubIndex']]
X
y=df['AQI']

# %%
df.columns
# Out:
# Index(['CO', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'PM10_SubIndex',
#        'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex',
#        'CO_SubIndex', 'AQI', 'AQI_Range', 'AQI_Bucket'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(X.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=40)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (354, 5) (153, 5) (354,) (153,)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_1 = lr.predict(X_test)

# %%
print("Root Mean Square Error: ", np.sqrt(mean_squared_error(y_test, y_pred_1)))
# Out:
# Root Mean Square Error:  22.517137423098507

# %%
print("Accuracy on Test data: ", lr.score(X_test, y_test))
# Out:
# Accuracy on Test data:  0.9509380618363422

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_2 = lr.predict(X_test)

# %%
print("Root Mean Square Error: ", np.sqrt(mean_squared_error(y_test, y_pred_2)))
# Out:
# Root Mean Square Error:  22.517137423098507

# %%
print("Accuracy on Test data: ", dtr.score(X_test, y_test))
# Out:
# Accuracy on Test data:  0.9571059053491626

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_3 = lr.predict(X_test)

# %%
print("Root Mean Square Error: ", np.sqrt(mean_squared_error(y_test, y_pred_3)))
# Out:
# Root Mean Square Error:  22.517137423098507

# %%
print("Accuracy on Test data: ", rf.score(X_test, y_test))
# Out:
# Accuracy on Test data:  0.9871744217630323
