# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
# data set labels
# > Time: Date and time when the data was collected
# > CO: Carbon Monoxide
# > RH: Relative Humidity
# > NO2: Nitrogran dioxide
# > Ozone: O3
# > PM10: Particulate Matter 10-micrometer in ug / m3
# > PM2.5: Particulate Matter 2.5-micrometer in ug / m3
# > SO2: Sulphur dioxide
# > Temp: Temprature in deg. Celcius at the data point when data was collected

# %%
df=pd.read_csv('ALL_Rabindra_Combined.csv')
df.head(50)
# Out:
#                 Time    CO     RH     NO2  Ozone   PM10  PM2.5    SO2   Temp
# 0   02-07-2019 00:15  2.30  58.06  206.94   4.69  389.4  231.2  11.52  18.74
# 1   02-07-2019 00:30  2.14  58.15  205.14   4.45  389.4  231.2  12.13  18.39
# 2   02-07-2019 00:45  1.86  59.70  195.08   4.32  404.6  238.1  11.60  17.99
# 3   02-07-2019 01:00  1.81  60.91  191.02   4.30  409.2  240.1  10.45  17.72
# 4   02-07-2019 01:15  1.86  61.01  190.17   4.53  409.2  240.1  10.36  17.95
# 5   02-07-2019 01:30  1.88  63.92  188.85   4.34  409.2  240.1   9.90  17.53
# 6   02-07-2019 01:45  1.88  65.23  189.71   4.07  410.1  230.0  10.70  17.36
# 7   02-07-2019 02:00  1.85  65.23  187.45   4.65  410.4  227.0  11.37  17.32
# 8   02-07-2019 02:15  1.82  66.85  190.28   4.73  410.4  227.0  11.20  16.98
# 9   02-07-2019 02:30  1.85  67.49  179.84   4.62  410.4  227.0  10.19  17.07
# 10  02-07-2019 02:45  1.88  65.23  189.71   4.07  410.1  230.0  10.70  17.36
# 11  02-07-2019 03:00  1.89  67.30  168.07   4.63  420.7  251.5   9.72  17.38
# 12  02-07-2019 03:15  1.91  68.88  167.58   4.76  420.7  251.5   9.51  17.03
# 13  02-07-2019 03:30  1.90  69.18  162.46   4.80  420.7  251.5   8.68  17.07
# 14  02-07-2019 03:45  1.86  67.19  177.21   4.31  418.3  245.8   9.81  17.27
# 15  02-07-2019 04:00  1.92  69.50  150.18   4.48  426.1  259.5   9.13  17.15
# 16  02-07-2019 04:15  1.85  70.90  144.49   4.70  426.1  259.5   7.26  16.94
# 17  02-07-2019 04:30  1.93  71.12  144.51   4.69  426.1  259.5   7.63  16.72
# 18  02-07-2019 04:45  1.86  70.69  158.90   4.43  424.9  257.6   8.80  16.76
# 19  02-07-2019 05:00  1.69  71.01  162.26   4.46  425.2  280.9   8.29  16.28
# 20  02-07-2019 05:15  1.53  71.42  153.00   4.26  425.2  280.9   7.96  16.17
# 21  02-07-2019 05:30  1.49  71.45  146.99   4.18  425.2  280.9   7.04  16.36
# 22  02-07-2019 05:45  1.80  71.89  153.78   5.06  425.4  275.9   7.81  16.55
# 23  02-07-2019 06:00  1.39  71.07  138.52   4.25  423.8  273.3   6.82  16.61
# 24  02-07-2019 06:15  1.34  72.07  129.76   3.70  423.8  273.3   6.33  16.59
# 25  02-07-2019 06:30  1.42  71.69  130.19   4.07  423.8  273.3   6.52  16.62
# 26  02-07-2019 06:45  1.44  71.69  142.52   4.10  424.1  275.1   7.11  16.20
# 27  02-07-2019 07:00  1.46  69.60  142.02   4.59  398.6  249.1   8.40  17.00
# 28  02-07-2019 07:15  1.48  67.50  145.11   5.01  398.6  249.1  10.03  17.48
# 29  02-07-2019 07:30  1.46  63.40  163.44   5.44  398.6  249.1  15.03  18.14
# 30  02-07-2019 07:45  1.45  69.41  134.12   4.12  404.2  254.5   7.48  16.85
# 31  02-07-2019 08:00  1.44  55.91  193.87   7.39  394.3  257.5  29.82  19.85
# 32  02-07-2019 08:15  1.41  53.57  204.34   8.96  394.3  257.5  31.46  20.51
# 33  02-07-2019 08:30  1.34  50.63  195.02  14.79  394.3  257.5  31.74  21.02
# 34  02-07-2019 08:45  1.44  59.25  183.49   5.90  395.3  255.6  23.47  18.88
# 35  02-07-2019 09:00  0.76  43.70   98.45  34.55  397.2  251.2  24.90  22.18
# 36  02-07-2019 09:15  0.71  41.89   88.19  38.33  397.2  251.2  22.95  22.72
# 37  02-07-2019 09:30  0.67  41.48   80.16  41.32  397.2  251.2  22.49  22.86
# 38  02-07-2019 09:45  1.00  47.01  140.32  28.30  396.5  252.7  27.08  21.60
# 39  02-07-2019 10:00  0.69  41.24   71.96  39.74  374.2  228.6  19.10  24.08
# 40  02-07-2019 10:15  0.67  39.61   69.47  41.23  374.2  228.6  19.23  24.64
# 41  02-07-2019 10:30  0.59  38.22   61.36  44.68  374.2  228.6  19.91  24.75
# 42  02-07-2019 10:45  0.67  41.48   75.17  41.13  379.6  233.9  19.95  23.33
# 43  02-07-2019 11:00  0.68  38.82   76.66  43.86  314.7  187.4  18.30  25.24
# 44  02-07-2019 11:15  0.68  38.05   76.88  42.94  314.7  187.4  19.97  26.05
# 45  02-07-2019 11:30  0.57  37.31   63.07  46.11  314.7  187.4  27.30  26.08
# 46  02-07-2019 11:45  0.69  37.52   74.48  42.05  328.6  197.0  18.83  25.50
# 47  02-07-2019 12:00  0.63  36.51   57.24  49.14  276.2  187.1  32.22  26.83
# 48  02-07-2019 12:15  0.67  36.47   56.68  51.67  276.2  187.1  32.74  26.60
# 49  02-07-2019 12:30  0.66  35.82   51.59  52.78  276.2  187.1  34.01  26.63

# %%
df.shape
# Out:
# (653, 9)

# %% [markdown]
# ### Extracting date and time

# %%
df[['Date', 'Time']]=df['Time'].str.split(' ',n=1, expand=True)
column_to_move = df.pop('Date')
df.insert(0, 'Date', column_to_move)
df.head()
# Out:
#          Date   Time    CO     RH     NO2  Ozone   PM10  PM2.5    SO2   Temp
# 0  02-07-2019  00:15  2.30  58.06  206.94   4.69  389.4  231.2  11.52  18.74
# 1  02-07-2019  00:30  2.14  58.15  205.14   4.45  389.4  231.2  12.13  18.39
# 2  02-07-2019  00:45  1.86  59.70  195.08   4.32  404.6  238.1  11.60  17.99
# 3  02-07-2019  01:00  1.81  60.91  191.02   4.30  409.2  240.1  10.45  17.72
# 4  02-07-2019  01:15  1.86  61.01  190.17   4.53  409.2  240.1  10.36  17.95

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2',
#        'Temp'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 653 entries, 0 to 652
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    653 non-null    object
#  1   Time    653 non-null    object
#  2   CO      647 non-null    float64
#  3   RH      647 non-null    float64
#  4   NO2     643 non-null    float64
#  5   Ozone   646 non-null    float64
#  6   PM10    644 non-null    float64
#  7   PM2.5   648 non-null    float64
#  8   SO2     646 non-null    float64
#  9   Temp    647 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 51.1+ KB

# %%
df.dtypes
# Out:
# Date      object
# Time      object
# CO       float64
# RH       float64
# NO2      float64
# Ozone    float64
# PM10     float64
# PM2.5    float64
# SO2      float64
# Temp     float64
# dtype: object

# %%
df.describe()
# Out:
#                CO          RH         NO2       Ozone        PM10       PM2.5  \
# count  647.000000  647.000000  643.000000  646.000000  644.000000  648.000000
# mean     0.926553   52.013864  105.049627   28.648824  263.005435  156.046914
# std      0.636700   13.706150   58.506829   17.066914  133.123076   76.265801
# min      0.350000   23.560000   33.880000    3.700000   92.600000    0.000000
# 25%      0.540000   39.520000   54.380000   11.677500  176.600000   99.600000
# 50%      0.740000   55.700000   84.110000   28.360000  246.200000  159.200000
# 75%      1.030000   63.540000  146.940000   44.302500  313.725000  195.300000
# max      4.670000   73.500000  271.820000   86.400000  889.500000  476.200000
#
#               SO2        Temp
# count  646.000000  647.000000
# mean    14.007771   19.543709
# std      8.109806    3.599355
# min      4.040000   14.140000
# 25%      8.080000   16.640000
# 50%     10.700000   18.180000
# 75%     18.937500   22.210000
# max     55.280000   28.390000

# %% [markdown]
# ### Checking for duplicated rows

# %%
# df[''.duplicated().sum()

# %%
df.drop_duplicates(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 0 to 652
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    522 non-null    object
#  1   Time    522 non-null    object
#  2   CO      516 non-null    float64
#  3   RH      516 non-null    float64
#  4   NO2     512 non-null    float64
#  5   Ozone   516 non-null    float64
#  6   PM10    513 non-null    float64
#  7   PM2.5   517 non-null    float64
#  8   SO2     515 non-null    float64
#  9   Temp    516 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 44.9+ KB

# %%
df = df.replace([None], np.nan)
df.sample(20)
# Out:
#            Date   Time    CO     RH     NO2  Ozone   PM10  PM2.5    SO2   Temp
# 575   2/13/2019  15:15  0.46  28.82   46.26  51.12  189.9  105.7   7.87  27.30
# 144  02-10-2019  12:00  0.36  30.05   35.52  52.24  151.3   80.6   9.69  22.91
# 591   2/13/2019  19:15  2.01  41.92  232.05   8.01  185.2  111.2  14.56  20.67
# 223  02-11-2019  07:45  0.85  68.70   96.45  12.23  184.6  116.4   8.56  14.42
# 166  02-10-2019  17:30  0.45  35.48   57.99  42.91  130.3   54.6   4.86  20.86
# 133  02-10-2019  09:15  0.51  45.54   50.01  42.33  129.1   72.3   9.46  19.70
# 436  02-12-2019  14:30  0.47  27.45   41.62  50.22  169.7   98.2  10.65  25.93
# 503   2/13/2019   7:15  1.06  67.41  149.47   8.86  256.0  171.2  28.36  16.73
# 175  02-10-2019  19:45  0.57  40.15   79.38  35.80  132.7   60.3   4.50  19.37
# 40   02-07-2019  10:15  0.67  39.61   69.47  41.23  374.2  228.6  19.23  24.64
# 203  02-11-2019  02:45  0.54  55.70   51.44  34.36  187.3  109.2   8.24  16.47
# 333  02-12-2019  01:00  1.00  63.36  134.77  17.19  407.6  260.9   8.08  16.64
# 364  02-12-2019  08:45  0.82  65.28  132.51  14.07  259.8  183.8  20.83  16.63
# 454  02-12-2019  19:00  0.99  38.78  202.40  10.69  159.8   97.9  12.45  20.64
# 302  02-11-2019  17:00  0.52  37.86   71.91  45.20  133.9   79.3   6.72  22.64
# 312  02-11-2019  19:30  0.72  48.82   68.68  41.43  161.8   87.3  13.68  19.58
# 173  02-10-2019  19:15  0.60  41.35   85.17  32.95  131.3   60.0   4.67  19.09
# 502   2/13/2019   7:00  1.05  67.97  155.42   8.17  256.0  171.2  27.02  16.47
# 65   02-07-2019  16:30  0.77  38.90   54.70  62.66  259.4  160.8  17.30  26.51
# 41   02-07-2019  10:30  0.59  38.22   61.36  44.68  374.2  228.6  19.91  24.75

# %%
df.isnull().sum()
# Out:
# Date      0
# Time      0
# CO        6
# RH        6
# NO2      10
# Ozone     6
# PM10      9
# PM2.5     5
# SO2       7
# Temp      6
# dtype: int64

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'Temp']] = df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'Temp']].astype(float, errors = 'raise')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522 entries, 0 to 652
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    522 non-null    object
#  1   Time    522 non-null    object
#  2   CO      516 non-null    float64
#  3   RH      516 non-null    float64
#  4   NO2     512 non-null    float64
#  5   Ozone   516 non-null    float64
#  6   PM10    513 non-null    float64
#  7   PM2.5   517 non-null    float64
#  8   SO2     515 non-null    float64
#  9   Temp    516 non-null    float64
# dtypes: float64(8), object(2)
# memory usage: 44.9+ KB

# %%
df['CO'].fillna(value=(df['CO'].mean()), inplace=True)
df['RH'].fillna(value=(df['RH'].mean()), inplace=True)
df['NO2'].fillna(value=(df['NO2'].mean()), inplace=True)
df['Ozone'].fillna(value=(df['Ozone'].mean()), inplace=True)
df['PM10'].fillna(value=(df['PM10'].mean()), inplace=True)
df['PM2.5'].fillna(value=(df['PM2.5'].mean()), inplace=True)
df['SO2'].fillna(value=(df['SO2'].mean()), inplace=True)
df['Temp'].fillna(value=(df['Temp'].mean()), inplace=True)

# %%
# removed null values
df.isnull().sum()
# Out:
# Date     0
# Time     0
# CO       0
# RH       0
# NO2      0
# Ozone    0
# PM10     0
# PM2.5    0
# SO2      0
# Temp     0
# dtype: int64

# %%
df.describe()
# Out:
#                CO          RH         NO2       Ozone        PM10       PM2.5  \
# count  522.000000  522.000000  522.000000  522.000000  522.000000  522.000000
# mean     0.961473   50.276415  107.900645   29.509903  262.551657  153.592650
# std      0.692972   14.156883   60.857923   17.881215  143.411567   81.871241
# min      0.350000   23.560000   33.880000    3.700000   92.600000    0.000000
# 25%      0.520000   36.837500   54.160000   11.125000  169.700000   87.700000
# 50%      0.740000   51.530000   87.675000   29.314952  237.000000  144.150000
# 75%      1.127500   62.985000  156.095000   46.507500  313.650000  194.025000
# max      4.670000   73.500000  271.820000   86.400000  889.500000  476.200000
#
#               SO2        Temp
# count  522.000000  522.000000
# mean    14.160874   20.112345
# std      8.396711    3.628847
# min      4.040000   14.140000
# 25%      8.042500   16.980000
# 50%     10.840000   19.325000
# 75%     19.065000   23.097500
# max     55.280000   28.390000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(data=df)

# %%
# plt.figure(figsize=(10, 7))

# %%
df.columns
# Out:
# Index(['Date', 'Time', 'CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2',
#        'Temp'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 7))
plt.boxplot(df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2']])
plt.xlabel("Factors affecting Air Quality")
# Out:
# Text(0.5, 0, 'Factors affecting Air Quality')

# %%
# removing outlier based on PM10
mean=df['PM10'].mean()
std_deviation=df['PM10'].std()
low_out=mean-3*std_deviation
high_out=mean+3*std_deviation
df=df[(df['PM10'] < high_out) & (df['PM10'] > low_out)]
df.reset_index()
# Out:
#      index        Date   Time    CO     RH     NO2  Ozone   PM10  PM2.5  \
# 0        0  02-07-2019  00:15  2.30  58.06  206.94   4.69  389.4  231.2
# 1        1  02-07-2019  00:30  2.14  58.15  205.14   4.45  389.4  231.2
# 2        2  02-07-2019  00:45  1.86  59.70  195.08   4.32  404.6  238.1
# 3        3  02-07-2019  01:00  1.81  60.91  191.02   4.30  409.2  240.1
# 4        4  02-07-2019  01:15  1.86  61.01  190.17   4.53  409.2  240.1
# ..     ...         ...    ...   ...    ...     ...    ...    ...    ...
# 498    648   2/14/2019   9:30  0.64  45.46   75.92  41.84  303.3  182.6
# 499    649   2/14/2019   9:45  0.70  50.84   86.33  39.09  306.8  191.1
# 500    650   2/14/2019  10:00  0.59  42.54   74.06  47.07  300.0  174.9
# 501    651   2/14/2019  10:15  0.57  41.85   68.83  51.51  300.0  174.9
# 502    652   2/14/2019  10:30  0.72  41.02   70.70  52.71  280.5  170.2
#
#        SO2   Temp
# 0    11.52  18.74
# 1    12.13  18.39
# 2    11.60  17.99
# 3    10.45  17.72
# 4    10.36  17.95
# ..     ...    ...
# 498  25.94  23.18
# 499  30.89  21.20
# 500  31.41  23.98
# 501  24.81  24.30
# 502  24.62  24.81
#
# [503 rows x 11 columns]

# %%
# shape of new dataframe
df.shape
# Out:
# (503, 10)

# %%
plt.figure(figsize=(10, 7))
plt.boxplot(df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2']])
plt.xlabel("Factors affecting Air Quality")
# Out:
# Text(0.5, 0, 'Factors affecting Air Quality')

# %%
df.head()
# Out:
#          Date   Time    CO     RH     NO2  Ozone   PM10  PM2.5    SO2   Temp
# 0  02-07-2019  00:15  2.30  58.06  206.94   4.69  389.4  231.2  11.52  18.74
# 1  02-07-2019  00:30  2.14  58.15  205.14   4.45  389.4  231.2  12.13  18.39
# 2  02-07-2019  00:45  1.86  59.70  195.08   4.32  404.6  238.1  11.60  17.99
# 3  02-07-2019  01:00  1.81  60.91  191.02   4.30  409.2  240.1  10.45  17.72
# 4  02-07-2019  01:15  1.86  61.01  190.17   4.53  409.2  240.1  10.36  17.95

# %%
df[['CO', 'RH', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2']].describe()
# Out:
#                CO          RH         NO2       Ozone        PM10       PM2.5  \
# count  503.000000  503.000000  503.000000  503.000000  503.000000  503.000000
# mean     0.888686   49.726657  104.253412   30.341629  241.518221  143.392372
# std      0.563023   14.102471   58.717439   17.685348   95.032469   63.650176
# min      0.350000   23.560000   33.880000    3.700000   92.600000    0.000000
# 25%      0.510000   36.490000   53.930000   13.125000  164.500000   87.450000
# 50%      0.720000   50.276415   83.450000   29.930000  228.700000  130.800000
# 75%      1.030000   62.185000  144.500000   46.780000  303.050000  189.400000
# max      4.670000   73.500000  271.820000   86.400000  601.000000  357.400000
#
#               SO2
# count  503.000000
# mean    13.580668
# std      7.724221
# min      4.040000
# 25%      7.940000
# 50%     10.510000
# 75%     17.930000
# max     50.290000

# %%
plt.hist(df[['CO']], bins=10, rwidth=0.75)
# Out:
# (array([289., 110.,  53.,  41.,   4.,   1.,   1.,   0.,   1.,   3.]),
#  array([0.35 , 0.782, 1.214, 1.646, 2.078, 2.51 , 2.942, 3.374, 3.806,
#         4.238, 4.67 ]),
#  <BarContainer object of 10 artists>)

# %%
df[['NO2']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['Ozone']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['PM2.5']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['PM10']].plot.hist(bins=10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.distplot(df['CO'], kde=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CO', ylabel='Density'>

# %%
sns.displot(df['RH'], kde=True)

# %%
sns.displot(df['NO2'], kde=True)

# %%
sns.displot(df['Ozone'], kde=True)

# %%
sns.displot(df['PM10'], kde=True)

# %%
sns.displot(df['PM2.5'], kde=True)

# %%
sns.displot(df['SO2'], kde=True)

# %% [markdown]
# ### Calculating Sub Indexes of different features affecting AQI based on Correlation Matrix
# ### A sub-index value is computed for each pollutant based on the pollutant's ambient air concentration. The highest sub-index value is then taken as the PSI value.

# %%
# PM10 Sub-Index calculation
def get_PM10_subindex(x):
    if x <= 50:
        return x
    elif x > 50 and x <= 100:
        return x
    elif x > 100 and x <= 250:
        return 100 + (x - 100) * 100 / 150
    elif x > 250 and x <= 350:
        return 200 + (x - 250)
    elif x > 350 and x <= 430:
        return 300 + (x - 350) * 100 / 80
    elif x > 430:
        return 400 + (x - 430) * 100 / 80
    else:
        return 0
    
df["PM10_SubIndex"] = df["PM10"].astype(int).apply(lambda x: get_PM10_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/837377662.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PM10_SubIndex"] = df["PM10"].astype(int).apply(lambda x: get_PM10_subindex(x))

# %%
# PM2.5 Sub-Index calculation
def get_PM25_subindex(x):
    if x <= 30:
        return x * 50 / 30
    elif x > 30 and x <= 60:
        return 50 + (x - 30) * 50 / 30
    elif x > 60 and x <= 90:
        return 100 + (x - 60) * 100 / 30
    elif x > 90 and x <= 120:
        return 200 + (x - 90) * 100 / 30
    elif x > 120 and x <= 250:
        return 300 + (x - 120) * 100 / 130
    elif x > 250:
        return 400 + (x - 250) * 100 / 130
    else:
        return 0

df["PM2.5_SubIndex"] = df["PM2.5"].astype(int).apply(lambda x: get_PM25_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/1245678504.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["PM2.5_SubIndex"] = df["PM2.5"].astype(int).apply(lambda x: get_PM25_subindex(x))

# %%
# SO2 Sub-Index calculation
def get_SO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 380:
        return 100 + (x - 80) * 100 / 300
    elif x > 380 and x <= 800:
        return 200 + (x - 380) * 100 / 420
    elif x > 800 and x <= 1600:
        return 300 + (x - 800) * 100 / 800
    elif x > 1600:
        return 400 + (x - 1600) * 100 / 800
    else:
        return 0

df["SO2_SubIndex"] = df["SO2"].astype(int).apply(lambda x: get_SO2_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/4072100297.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["SO2_SubIndex"] = df["SO2"].astype(int).apply(lambda x: get_SO2_subindex(x))

# %%
# NO2 Sub-Index calculation
def get_NO2_subindex(x):
    if x <= 40:
        return x * 50 / 40
    elif x > 40 and x <= 80:
        return 50 + (x - 40) * 50 / 40
    elif x > 80 and x <= 180:
        return 100 + (x - 80) * 100 / 100
    elif x > 180 and x <= 280:
        return 200 + (x - 180) * 100 / 100
    elif x > 280 and x <= 400:
        return 300 + (x - 280) * 100 / 120
    elif x > 400:
        return 400 + (x - 400) * 100 / 120
    else:
        return 0

df["NO2_SubIndex"] = df["NO2"].astype(int).apply(lambda x: get_NO2_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/1061408014.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NO2_SubIndex"] = df["NO2"].astype(int).apply(lambda x: get_NO2_subindex(x))

# %%
# Ozone Sub-Index calculation
def get_Ozone_subindex(x):
    if x <= 50:
        return x * 50 / 50
    elif x > 50 and x <= 100:
        return 50 + (x - 50) * 50 / 50
    elif x > 100 and x <= 168:
        return 100 + (x - 100) * 100 / 68
    elif x > 168 and x <= 208:
        return 200 + (x - 168) * 100 / 40
    elif x > 208 and x <= 748:
        return 300 + (x - 208) * 100 / 539
    elif x > 748:
        return 400 + (x - 400) * 100 / 539
    else:
        return 0

df["Ozone_SubIndex"] = df["Ozone"].astype(int).apply(lambda x: get_Ozone_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/3412462845.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Ozone_SubIndex"] = df["Ozone"].astype(int).apply(lambda x: get_Ozone_subindex(x))

# %%
# Removing columns
df.drop(['Date', 'Time', 'Temp', 'RH'], axis=1, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
def get_CO_subindex(x):
    if x <= 1:
        return x * 50 / 1
    elif x <= 2:
        return 50 + (x - 1) * 50 / 1
    elif x <= 10:
        return 100 + (x - 2) * 100 / 8
    elif x <= 17:
        return 200 + (x - 10) * 100 / 7
    elif x <= 34:
        return 300 + (x - 17) * 100 / 17
    elif x > 34:
        return 400 + (x - 34) * 100 / 17
    else:
        return 0

df["CO_SubIndex"] = df["CO"].apply(lambda x: get_CO_subindex(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/2719783207.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["CO_SubIndex"] = df["CO"].apply(lambda x: get_CO_subindex(x))

# %%
df["AQI"] = (round(df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex']].max(axis = 1)))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/4100597417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AQI"] = (round(df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex']].max(axis = 1)))

# %%
df.columns
# Out:
# Index(['CO', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'PM10_SubIndex',
#        'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex',
#        'CO_SubIndex', 'AQI'],
#       dtype='object')

# %%
sns.histplot(df['PM10_SubIndex'], kde=True)
# Out:
# <AxesSubplot:xlabel='PM10_SubIndex', ylabel='Count'>

# %%
sns.histplot(df['PM2.5_SubIndex'], kde=True)
# Out:
# <AxesSubplot:xlabel='PM2.5_SubIndex', ylabel='Count'>

# %%
sns.histplot(df['SO2_SubIndex'], kde=True)
# Out:
# <AxesSubplot:xlabel='SO2_SubIndex', ylabel='Count'>

# %%
sns.histplot(df['NO2_SubIndex'], kde=True)
# Out:
# <AxesSubplot:xlabel='NO2_SubIndex', ylabel='Count'>

# %%
sns.histplot(df['Ozone_SubIndex'], kde=True)
# Out:
# <AxesSubplot:xlabel='Ozone_SubIndex', ylabel='Count'>

# %%
sns.histplot(df['CO_SubIndex'], kde=True)
# Out:
# <AxesSubplot:xlabel='CO_SubIndex', ylabel='Count'>

# %%
def AQI_Range(x):
    if x <= 100 :
        return "Good"
    elif x > 100 and x <= 200:
        return "Moderate"
    else:
        return "Bad"

df['AQI_Range'] = df['AQI'] .apply(AQI_Range)
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/3809285243.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['AQI_Range'] = df['AQI'] .apply(AQI_Range)

# %%
def get_AQI_Bucket(x):
    if x=='Good':
        return 0
    elif x=='Moderate':
        return 1
    elif x=='Poor':
        return 2
    elif x=='Unhealthy':
        return 3
    elif x=='Very unhealthy':
        return 4
    else:
        return 5
    
df["AQI_Bucket"]=df["AQI"].apply(lambda x: get_AQI_Bucket(x))
# Out:
# C:\Users\mohsi\AppData\Local\Temp/ipykernel_12412/3488882346.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["AQI_Bucket"]=df["AQI"].apply(lambda x: get_AQI_Bucket(x))

# %%
df.head()
# Out:
#      CO     NO2  Ozone   PM10  PM2.5    SO2  PM10_SubIndex  PM2.5_SubIndex  \
# 0  2.30  206.94   4.69  389.4  231.2  11.52         348.75      385.384615
# 1  2.14  205.14   4.45  389.4  231.2  12.13         348.75      385.384615
# 2  1.86  195.08   4.32  404.6  238.1  11.60         367.50      390.769231
# 3  1.81  191.02   4.30  409.2  240.1  10.45         373.75      392.307692
# 4  1.86  190.17   4.53  409.2  240.1  10.36         373.75      392.307692
#
#    SO2_SubIndex  NO2_SubIndex  Ozone_SubIndex  CO_SubIndex    AQI AQI_Range  \
# 0         13.75         226.0             4.0       103.75  385.0       Bad
# 1         15.00         225.0             4.0       101.75  385.0       Bad
# 2         13.75         215.0             4.0        93.00  391.0       Bad
# 3         12.50         211.0             4.0        90.50  392.0       Bad
# 4         12.50         210.0             4.0        93.00  392.0       Bad
#
#    AQI_Bucket
# 0           5
# 1           5
# 2           5
# 3           5
# 4           5

# %%
df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex', 'CO_SubIndex',]].plot(figsize=(16,6))
plt.xlabel('Count')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
df['AQI_Range'].value_counts()
# Out:
# Bad         364
# Moderate    139
# Name: AQI_Range, dtype: int64

# %%
X=df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex', 'CO_SubIndex']]
X
y=df['AQI']

# %%
df.columns
# Out:
# Index(['CO', 'NO2', 'Ozone', 'PM10', 'PM2.5', 'SO2', 'PM10_SubIndex',
#        'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex',
#        'CO_SubIndex', 'AQI', 'AQI_Range', 'AQI_Bucket'],
#       dtype='object')

# %%
X.columns
# Out:
# Index(['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex',
#        'Ozone_SubIndex', 'CO_SubIndex'],
#       dtype='object')

# %%
X.describe()
# Out:
#        PM10_SubIndex  PM2.5_SubIndex  SO2_SubIndex  NO2_SubIndex  \
# count     503.000000      503.000000    503.000000    503.000000
# mean      208.018721      276.724780     16.354374    120.737575
# std        85.888130       99.325522      9.650661     61.586131
# min        92.000000        0.000000      5.000000     41.250000
# 25%       142.666667      190.000000      8.750000     66.250000
# 50%       185.333333      307.692308     12.500000    103.000000
# 75%       253.000000      353.076923     21.875000    164.000000
# max       613.750000      482.307692     62.500000    291.000000
#
#        Ozone_SubIndex  CO_SubIndex
# count      503.000000   503.000000
# mean        29.838966    43.499387
# std         17.660361    23.714156
# min          3.000000    17.500000
# 25%         13.000000    25.500000
# 50%         29.000000    36.000000
# 75%         46.000000    51.500000
# max         86.000000   133.375000

# %%
plt.figure(figsize=(10, 7))
plt.boxplot(df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex', 'CO_SubIndex']])
plt.xlabel("Factors affecting Air Quality")
# Out:
# Text(0.5, 0, 'Factors affecting Air Quality')

# %%
sns.pairplot(data=X)

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(X.corr(), annot=True, cmap='Blues', linewidths=3, linecolor='k')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Training

# %%
scores = []

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=40)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (352, 6) (151, 6) (352,) (151,)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_1 = lr.predict(X_test)

# %%
print("Root Mean Square Error: ", np.sqrt(mean_squared_error(y_test, y_pred_1)))
# Out:
# Root Mean Square Error:  12.806516504232478

# %%
print("Accuracy on Test data: ", lr.score(X_test, y_test))
scores.append(lr.score(X_test, y_test))
# Out:
# Accuracy on Test data:  0.9832498774878109

# %% [markdown]
# ## Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr = DecisionTreeRegressor()
dtr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred_2 = lr.predict(X_test)

# %%
print("Root Mean Square Error: ", np.sqrt(mean_squared_error(y_test, y_pred_2)))
# Out:
# Root Mean Square Error:  12.806516504232478

# %%
print("Accuracy on Test data: ", dtr.score(X_test, y_test))
scores.append(dtr.score(X_test, y_test))
# Out:
# Accuracy on Test data:  0.99505241409082

# %% [markdown]
# ## Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred_3 = lr.predict(X_test)

# %%
print("Root Mean Square Error: ", np.sqrt(mean_squared_error(y_test, y_pred_3)))
# Out:
# Root Mean Square Error:  12.806516504232478

# %%
print("Accuracy on Test data: ", rf.score(X_test, y_test))
scores.append(rf.score(X_test, y_test))
# Out:
# Accuracy on Test data:  0.9932574067237628

# %% [markdown]
# ## SVM Regressor

# %%
from sklearn.svm import SVR
svr = SVR()
svr.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred_4 = svr.predict(X_test)

# %%
print("Root Mean Square Error: ", np.sqrt(mean_squared_error(y_test, y_pred_4)))
# Out:
# Root Mean Square Error:  52.1696733623425

# %%
print("Accuracy on Test data: ", svr.score(X_test, y_test))
scores.append(svr.score(X_test, y_test))
# Out:
# Accuracy on Test data:  0.7220336681663799

# %%
names = ["Linear Regression",
         "Decision Tree Regression",
         "Random Forest Regression",
         "SVM Regression"]

# %%
df_stat = pd.DataFrame()
df_stat['models'] = names
df_stat['score'] = scores
df_stat
# Out:
#                      models     score
# 0         Linear Regression  0.983250
# 1  Decision Tree Regression  0.995052
# 2  Random Forest Regression  0.993257
# 3            SVM Regression  0.722034

# %%
plt.figure(figsize=(4, 4))
sns.set(style="whitegrid")
ax = sns.barplot(y="models", x="score", data=df_stat, palette='winter')

# %% [markdown]
# ## Applying Classification models

# %%
# target value will be AQI_Class

# %%
X
# Out:
#      PM10_SubIndex  PM2.5_SubIndex  SO2_SubIndex  NO2_SubIndex  \
# 0           348.75      385.384615         13.75        226.00
# 1           348.75      385.384615         15.00        225.00
# 2           367.50      390.769231         13.75        215.00
# 3           373.75      392.307692         12.50        211.00
# 4           373.75      392.307692         12.50        210.00
# ..             ...             ...           ...           ...
# 648         253.00      347.692308         31.25         93.75
# 649         256.00      354.615385         37.50        106.00
# 650         250.00      341.538462         38.75         92.50
# 651         250.00      341.538462         30.00         85.00
# 652         230.00      338.461538         30.00         87.50
#
#      Ozone_SubIndex  CO_SubIndex
# 0               4.0       103.75
# 1               4.0       101.75
# 2               4.0        93.00
# 3               4.0        90.50
# 4               4.0        93.00
# ..              ...          ...
# 648            41.0        32.00
# 649            39.0        35.00
# 650            47.0        29.50
# 651            51.0        28.50
# 652            52.0        36.00
#
# [503 rows x 6 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=42)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (352, 6) (151, 6) (352,) (151,)

# %%
y_map = y_test.map({"Bad": 0, "Moderate": 1})

# %%
X=df[['PM10_SubIndex', 'PM2.5_SubIndex', 'SO2_SubIndex', 'NO2_SubIndex', 'Ozone_SubIndex', 'CO_SubIndex']]
X
y=df['AQI_Range']

# %%
y.value_counts()
# Out:
# Bad         364
# Moderate    139
# Name: AQI_Range, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, mean_squared_error
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.3, random_state=40)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (352, 6) (151, 6) (352,) (151,)

# %%
# creating a list for storing the results of each model
scores_classification=[]

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(max_iter=5000)

model1=lr.fit(X_train,y_train)
prediction1=model1.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report
cm=confusion_matrix(y_test,prediction1)
y_test.isna().sum()
# Out:
# 0

# %%
sns.heatmap(cm, annot=True, fmt = 'd',linewidths=3, linecolor='k', cmap='Blues')
plt.title("Logistic Regression")
# Out:
# Text(0.5, 1.0, 'Logistic Regression')

# %%
print(classification_report(y_test,prediction1))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.95      0.98      0.97       106
#     Moderate       0.95      0.89      0.92        45
#
#     accuracy                           0.95       151
#    macro avg       0.95      0.94      0.94       151
# weighted avg       0.95      0.95      0.95       151

# %%
scores_classification.append(accuracy_score(y_test,prediction1))
accuracy_score(y_test,prediction1)
y_map.isna().sum()
# Out:
# 151

# %%
from sklearn.metrics import roc_auc_score, roc_curve

plt.figure(figsize=(6, 4))
fpr, tpr, thresholds = roc_curve(y_map, lr.predict_proba(X_test)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Logistic Regression')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='orange',lw=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12412/135123575.py in <module>
#       2
#       3 plt.figure(figsize=(6, 4))
# ----> 4 fpr, tpr, thresholds = roc_curve(y_map, lr.predict_proba(X_test)[:,1],drop_intermediate=False)
#       5 plt.xlim([0.0, 1.0])
#       6 plt.ylim([0.0, 1.0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     977
#     978     """
# --> 979     fps, tps, thresholds = _binary_clf_curve(
#     980         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     981     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     734     """
#     735     # Check to make sure y_true is valid
# --> 736     y_type = type_of_target(y_true, input_name="y_true")
#     737     if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     738         raise ValueError("{0} format is not supported".format(y_type))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y, input_name)
#     330     if y.dtype.kind == "f" and np.any(y != y.astype(int)):
#     331         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 332         _assert_all_finite(y, input_name=input_name)
#     333         return "continuous" + suffix
#     334
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input y_true contains NaN.

# %% [markdown]
# ### Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dtc=DecisionTreeClassifier(criterion='log_loss', max_depth=15, min_samples_leaf=1, min_samples_split=2)
model2=dtc.fit(X_train,y_train)
prediction2=model2.predict(X_test)
cm2= confusion_matrix(y_test,prediction2)

# %%
cm=confusion_matrix(y_test,prediction2)
sns.heatmap(cm, annot=True, fmt = 'd', linewidths=3, linecolor='k', cmap='Blues')
plt.title("Decision Tree Classifier")
# Out:
# Text(0.5, 1.0, 'Decision Tree Classifier')

# %%
print(classification_report(y_test,prediction2))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       1.00      1.00      1.00       106
#     Moderate       1.00      1.00      1.00        45
#
#     accuracy                           1.00       151
#    macro avg       1.00      1.00      1.00       151
# weighted avg       1.00      1.00      1.00       151

# %%
scores_classification.append(accuracy_score(y_test,prediction1))
accuracy_score(y_test,prediction2)
# Out:
# 1.0

# %%
from sklearn.metrics import roc_auc_score, roc_curve

plt.figure(figsize=(6, 4))
fpr, tpr, thresholds = roc_curve(y_map, dtc.predict_proba(X_test)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Decision Tree Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='yellow',lw=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12412/2460946658.py in <module>
#       2
#       3 plt.figure(figsize=(6, 4))
# ----> 4 fpr, tpr, thresholds = roc_curve(y_map, dtc.predict_proba(X_test)[:,1],drop_intermediate=False)
#       5 plt.xlim([0.0, 1.0])
#       6 plt.ylim([0.0, 1.0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     977
#     978     """
# --> 979     fps, tps, thresholds = _binary_clf_curve(
#     980         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     981     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     734     """
#     735     # Check to make sure y_true is valid
# --> 736     y_type = type_of_target(y_true, input_name="y_true")
#     737     if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     738         raise ValueError("{0} format is not supported".format(y_type))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y, input_name)
#     330     if y.dtype.kind == "f" and np.any(y != y.astype(int)):
#     331         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 332         _assert_all_finite(y, input_name=input_name)
#     333         return "continuous" + suffix
#     334
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input y_true contains NaN.

# %% [markdown]
# ### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier(bootstrap=False,
 max_depth=6,
 max_features='auto',
 min_samples_leaf=1,
 min_samples_split=2,
 n_estimators=10)

model3 = rfc.fit(X_train, y_train)
prediction3 = model3.predict(X_test)
cm3=confusion_matrix(y_test, prediction3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:427: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
sns.heatmap(cm3, annot=True, linewidths=3, linecolor='k', cmap='Blues', fmt='d')
# Out:
# <AxesSubplot:>

# %%
print(classification_report(y_test,prediction3))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       1.00      1.00      1.00       106
#     Moderate       1.00      1.00      1.00        45
#
#     accuracy                           1.00       151
#    macro avg       1.00      1.00      1.00       151
# weighted avg       1.00      1.00      1.00       151

# %%
scores_classification.append(accuracy_score(y_test,prediction3))
accuracy_score(y_test,prediction3)
# Out:
# 1.0

# %%
from sklearn.metrics import roc_auc_score, roc_curve

plt.figure(figsize=(6, 4))
fpr, tpr, thresholds = roc_curve(y_map, rfc.predict_proba(X_test)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Random Forest Classifier')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='green',lw=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12412/1968527140.py in <module>
#       2
#       3 plt.figure(figsize=(6, 4))
# ----> 4 fpr, tpr, thresholds = roc_curve(y_map, rfc.predict_proba(X_test)[:,1],drop_intermediate=False)
#       5 plt.xlim([0.0, 1.0])
#       6 plt.ylim([0.0, 1.0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     977
#     978     """
# --> 979     fps, tps, thresholds = _binary_clf_curve(
#     980         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     981     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     734     """
#     735     # Check to make sure y_true is valid
# --> 736     y_type = type_of_target(y_true, input_name="y_true")
#     737     if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     738         raise ValueError("{0} format is not supported".format(y_type))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y, input_name)
#     330     if y.dtype.kind == "f" and np.any(y != y.astype(int)):
#     331         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 332         _assert_all_finite(y, input_name=input_name)
#     333         return "continuous" + suffix
#     334
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input y_true contains NaN.

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC

svm=SVC(kernel='linear', probability=True)
model4=svm.fit(X_train,y_train)
prediction4=model4.predict(X_test)
cm4= confusion_matrix(y_test,prediction4)

# %%
sns.heatmap(cm4, annot=True, fmt='d', linewidths=3, linecolor='k', cmap='Blues')
plt.title("Support Vector Classifier")
# Out:
# Text(0.5, 1.0, 'Support Vector Classifier')

# %%
print(classification_report(y_test,prediction4))
# Out:
#               precision    recall  f1-score   support
#
#          Bad       0.95      0.98      0.97       106
#     Moderate       0.95      0.89      0.92        45
#
#     accuracy                           0.95       151
#    macro avg       0.95      0.94      0.94       151
# weighted avg       0.95      0.95      0.95       151

# %%
scores_classification.append(accuracy_score(y_test,prediction4))
accuracy_score(y_test, prediction4)
# Out:
# 0.9536423841059603

# %%
from sklearn.metrics import roc_auc_score, roc_curve

plt.figure(figsize=(6, 4))
fpr, tpr, thresholds = roc_curve(y_map, svm.predict_proba(X_test)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Logistic Regression')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='Brown',lw=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12412/2965934349.py in <module>
#       2
#       3 plt.figure(figsize=(6, 4))
# ----> 4 fpr, tpr, thresholds = roc_curve(y_map, svm.predict_proba(X_test)[:,1],drop_intermediate=False)
#       5 plt.xlim([0.0, 1.0])
#       6 plt.ylim([0.0, 1.0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     977
#     978     """
# --> 979     fps, tps, thresholds = _binary_clf_curve(
#     980         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     981     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     734     """
#     735     # Check to make sure y_true is valid
# --> 736     y_type = type_of_target(y_true, input_name="y_true")
#     737     if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     738         raise ValueError("{0} format is not supported".format(y_type))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y, input_name)
#     330     if y.dtype.kind == "f" and np.any(y != y.astype(int)):
#     331         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 332         _assert_all_finite(y, input_name=input_name)
#     333         return "continuous" + suffix
#     334
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input y_true contains NaN.

# %% [markdown]
# ### Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

NB = GaussianNB(var_smoothing= 2e-9)
model5 = NB.fit(X_train, y_train)
prediction5 = model5.predict(X_test)
cm5=confusion_matrix(y_test, prediction5)

# %%
sns.heatmap(cm5, annot=True, fmt='d', linewidths=3, linecolor='k', cmap='Blues')
plt.title("Naive Bayes")
# Out:
# Text(0.5, 1.0, 'Naive Bayes')

# %%
print(classification_report(y_test, prediction5))
accuracy_score(y_test, prediction5)
# Out:
#               precision    recall  f1-score   support
#
#          Bad       1.00      0.94      0.97       106
#     Moderate       0.88      1.00      0.94        45
#
#     accuracy                           0.96       151
#    macro avg       0.94      0.97      0.95       151
# weighted avg       0.96      0.96      0.96       151
# 0.9602649006622517

# %%
scores_classification.append(accuracy_score(y_test,prediction5))

# %%
from sklearn.metrics import roc_auc_score, roc_curve

plt.figure(figsize=(6, 4))
fpr, tpr, thresholds = roc_curve(y_map, NB.predict_proba(X_test)[:,1],drop_intermediate=False)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC Logistic Regression')
plt.xlabel('False Positive Rate, (1 - Specificity)')
plt.ylabel('True Positive Rate, (Sensitivity)')
plt.plot(fpr, tpr,color='Grey',lw=5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12412/291420511.py in <module>
#       2
#       3 plt.figure(figsize=(6, 4))
# ----> 4 fpr, tpr, thresholds = roc_curve(y_map, NB.predict_proba(X_test)[:,1],drop_intermediate=False)
#       5 plt.xlim([0.0, 1.0])
#       6 plt.ylim([0.0, 1.0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     977
#     978     """
# --> 979     fps, tps, thresholds = _binary_clf_curve(
#     980         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     981     )
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     734     """
#     735     # Check to make sure y_true is valid
# --> 736     y_type = type_of_target(y_true, input_name="y_true")
#     737     if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
#     738         raise ValueError("{0} format is not supported".format(y_type))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\multiclass.py in type_of_target(y, input_name)
#     330     if y.dtype.kind == "f" and np.any(y != y.astype(int)):
#     331         # [.1, .2, 3] or [[.1, .2, 3]] or [[1., .2]] and not [1., 2., 3.]
# --> 332         _assert_all_finite(y, input_name=input_name)
#     333         return "continuous" + suffix
#     334
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input y_true contains NaN.

# %%
model_names = ["Logistic Regression",
               "Decision Tree Classifier",
               "Random Forest Classifier",
               "Support Vector Classifier",
               "Naive Bayes"]

# %%
df_stat = pd.DataFrame()
df_stat['models'] = model_names
df_stat['score'] = scores_classification
df_stat
# Out:
#                       models     score
# 0        Logistic Regression  0.953642
# 1   Decision Tree Classifier  0.953642
# 2   Random Forest Classifier  1.000000
# 3  Support Vector Classifier  0.953642
# 4                Naive Bayes  0.960265

# %%
plt.figure(figsize=(4, 4))
sns.set(style="whitegrid")
ax = sns.barplot(y="models", x="score", data=df_stat, palette='winter', errwidth=50)
